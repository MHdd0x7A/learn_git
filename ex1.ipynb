# %%
import pandas as pd
df = pd.read_csv('../2018-chienyeh_utf8.csv')
df.head()
# Out:
#    銷貨倉      銷貨日期   銷貨次數    序號      銷貨時間  銷售金額         客戶代號  性別  \
# 0  09
#   2018/1/1  10001  1001  10:23:00  2500  0919323538
#    女
# 1  13
#   2018/1/1  10001  1001  12:52:52  2574  572
#    女
# 2  03
#   2018/1/1  10001  1001  08:58:08  2824  C01
#
# 3  05
#   2018/1/1  10001  1001  11:20:48  2849  E01
#    男
# 4  18
#   2018/1/1  10001  1001  09:00:34  2948  0933131405
#    男
#
#              藥品代號                                               藥品名稱  ...  \
# 0  009571
#   作預付2500元-全身芳療舒壓課程-09倉                         ...  ...
# 1  4710050921359
#   KB99無子大葡萄乾300G                                ...  ...
# 2  4715168110572
#   永信后保寧1.5MG(事後)1錠入                             ...  ...
# 3  4716022950143
#   防疫天使嬰幼童口罩5入(綠.藍)                              ...  ...
# 4  4901548160132
#   暖暖包24H 日本桐灰(小白兔)10入                           ...  ...
#
#                             說明 等級    原價  折扣率  交易後庫存量      售價  銷售量   銷售額  折扣金  \
# ...
